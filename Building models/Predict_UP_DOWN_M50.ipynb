# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import metrics

# %%
import os
DATA_PATH = "Dane/USA/SP_500.csv"

# %%
data_stock = pd.read_csv(DATA_PATH, sep=",")

# %%
data_stock.head()
# Out:
#          Date     Open     High      Low    Close      Volume
# 0  2012-01-30  1316.16  1316.16  1300.49  1313.01  2032783333
# 1  2012-01-31  1313.53  1321.41  1306.69  1312.41  2353083333
# 2  2012-02-01  1312.45  1330.52  1312.45  1324.09  2502422222
# 3  2012-02-02  1324.24  1329.19  1321.57  1325.54  2289400000
# 4  2012-02-03  1326.21  1345.34  1326.21  1344.90  2560305556

# %%
data_stock.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1592.000000  1592.000000  1592.000000  1592.000000  1.592000e+03
# mean   1983.254391  1991.843769  1974.077142  1983.754906  1.973925e+09
# std     385.776016   386.468906   384.702618   385.463489  3.629619e+08
# min    1277.820000  1282.550000  1266.740000  1278.040000  6.938667e+08
# 25%    1687.297500  1692.052500  1681.657500  1688.845000  1.762729e+09
# 50%    2018.305000  2026.790000  2005.280000  2019.180000  1.935067e+09
# 75%    2177.872500  2183.827500  2171.437500  2180.080000  2.129876e+09
# max    2867.230000  2872.870000  2851.480000  2872.870000  4.220806e+09

# %%
data_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1592 non-null   object
#  1   Open    1592 non-null   float64
#  2   High    1592 non-null   float64
#  3   Low     1592 non-null   float64
#  4   Close   1592 non-null   float64
#  5   Volume  1592 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 74.8+ KB

# %% [markdown]
# Dodajmy kolumnę wskazującą czy podczas danej sesji kurs wzrósł czy zmalał

# %%
#1 - wzrósł
#0 - zmalał
data_stock['Increased'] = data_stock['Close']-data_stock['Open']
data_stock['Increased'] = data_stock['Increased'].map(lambda diff: 1 if diff > 0 else 0)

# %%
data_stock.head()
# Out:
#          Date     Open     High      Low    Close      Volume  Increased
# 0  2012-01-30  1316.16  1316.16  1300.49  1313.01  2032783333          0
# 1  2012-01-31  1313.53  1321.41  1306.69  1312.41  2353083333          0
# 2  2012-02-01  1312.45  1330.52  1312.45  1324.09  2502422222          1
# 3  2012-02-02  1324.24  1329.19  1321.57  1325.54  2289400000          1
# 4  2012-02-03  1326.21  1345.34  1326.21  1344.90  2560305556          1

# %% [markdown]
# Zróbmy wykres CLOSE w zależności od czasu

# %%
import matplotlib.pyplot as plt

# %%
plt.subplots(figsize = (20, 5))
plt.plot(data_stock['Close'], label = 'CLOSE')
# plt.ylim([-0.004, 0.004])
# plt.xlim([0, 1660])
plt.ylabel('CLOSE Value')
plt.xlabel('Days')
plt.title('CLOSE values')
plt.legend()
plt.show()

# %% [markdown]
# Spójrzmy na wycinek dzienny (7 dni)

# %%
plt.subplots(figsize = (20, 5))
plt.plot(data_stock['Close'][:8], label = 'CLOSE')
plt.xlim([0, 7])
plt.ylabel('CLOSE Value')
plt.xlabel('Days')
plt.title('CLOSE values')
plt.legend()
plt.show()

# %%
import seaborn as sns

# sns.set(style='darkgrid')

corr = data_stock.corr()
f, ax = plt.subplots(figsize=(10, 10))
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, cmap=cmap, vmin=-1, vmax=1,
            square=True, xticklabels=True, yticklabels=True,
            linewidths=.5, cbar_kws={'shrink': .5}, ax=ax)
plt.show()

# %% [markdown]
# # Podzielenie danych na X i y

# %% [markdown]
# Będziemy próbowali przewidzieć czy kurs wzrośnie czy zmaleje podczas danej sesji

# %% [markdown]
# Wykorzystamy w tym celu kolumny VOL oraz inforację czy wtedy kurs wzrósł czy zmalał

# %% [markdown]
# Spróbujemy to zrobić wykorzystując **n poprzednich danych**

# %% [markdown]
# W tym celu utwórzmy kopię naszego dataframe *wig* aby móc dodać do niego dodatkowe kolumny wykorzystujące informacje z przeszłości

# %%
data_stock_modified = data_stock

# %%
data_stock_modified.head()
# Out:
#          Date     Open     High      Low    Close      Volume  Increased
# 0  2012-01-30  1316.16  1316.16  1300.49  1313.01  2032783333          0
# 1  2012-01-31  1313.53  1321.41  1306.69  1312.41  2353083333          0
# 2  2012-02-01  1312.45  1330.52  1312.45  1324.09  2502422222          1
# 3  2012-02-02  1324.24  1329.19  1321.57  1325.54  2289400000          1
# 4  2012-02-03  1326.21  1345.34  1326.21  1344.90  2560305556          1

# %% [markdown]
# Usuńmy n pierwszych wiersze z naszych danych, gdyż dla nich nie będziemy mieli danych z przeszłości

# %%
memory = 50

# %%
data_stock_modified = data_stock_modified[memory:]

# %%
for i in range (1, memory+1):
    data_stock_modified['Vol_'+str(i)+'_ago'] = np.array(data_stock['Volume'][memory-i:-i])
    data_stock_modified['Increased_'+str(i)+'_ago'] = np.array(data_stock['Increased'][memory-i:-i])
# Out:
# <ipython-input-132-a2f7d989ca09>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_stock_modified['Vol_'+str(i)+'_ago'] = np.array(data_stock['Volume'][memory-i:-i])
# <ipython-input-132-a2f7d989ca09>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_stock_modified['Increased_'+str(i)+'_ago'] = np.array(data_stock['Increased'][memory-i:-i])

# %%
data_stock_modified.head(6)
# Out:
#           Date     Open     High      Low    Close      Volume  Increased  \
# 50  2012-04-11  1358.98  1374.71  1358.98  1368.71  2079466667          1
# 51  2012-04-12  1368.77  1388.13  1368.77  1387.57  2010155556          1
# 52  2012-04-13  1387.61  1387.61  1369.85  1370.26  2017311111          0
# 53  2012-04-16  1370.27  1379.66  1365.38  1369.57  1985988889          0
# 54  2012-04-17  1369.57  1392.76  1369.57  1390.78  1920111111          1
# 55  2012-04-18  1390.78  1390.78  1383.29  1385.14  1923966667          0
#
#      Vol_1_ago  Increased_1_ago   Vol_2_ago  ...  Vol_46_ago  \
# 50  2573183333                0  1927211111  ...  2560305556
# 51  2079466667                1  2573183333  ...  1877611111
# 52  2010155556                1  2079466667  ...  2079144444
# 53  2017311111                0  2010155556  ...  2275961111
# 54  1985988889                0  2017311111  ...  2338827778
# 55  1920111111                1  1985988889  ...  2154211111
#
#     Increased_46_ago  Vol_47_ago  Increased_47_ago  Vol_48_ago  \
# 50                 1  2289400000                 1  2502422222
# 51                 1  2560305556                 1  2289400000
# 52                 1  1877611111                 1  2560305556
# 53                 1  2079144444                 1  1877611111
# 54                 1  2275961111                 1  2079144444
# 55                 0  2338827778                 1  2275961111
#
#     Increased_48_ago  Vol_49_ago  Increased_49_ago  Vol_50_ago  \
# 50                 1  2353083333                 0  2032783333
# 51                 1  2502422222                 1  2353083333
# 52                 1  2289400000                 1  2502422222
# 53                 1  2560305556                 1  2289400000
# 54                 1  1877611111                 1  2560305556
# 55                 1  2079144444                 1  1877611111
#
#     Increased_50_ago
# 50                 0
# 51                 0
# 52                 1
# 53                 1
# 54                 1
# 55                 1
#
# [6 rows x 107 columns]

# %%
sns.set(style='darkgrid')

corr = data_stock_modified.corr()
f, ax = plt.subplots(figsize=(25, 25))
cmap = sns.diverging_palette(220, 10, as_cmap=True)

sns.heatmap(corr, cmap=cmap, vmin=-1, vmax=1,
            square=True, xticklabels=True, yticklabels=True,
            linewidths=.5, cbar_kws={'shrink': .5}, ax=ax)
plt.show()

# %% [markdown]
# **Możemy teraz utworzyć nasze zbiory X oraz y**

# %% [markdown]
# Wydzielamy zbiór wartości

# %%
y = data_stock_modified['Increased'].values

# %%
y
# Out:
# array([1, 1, 0, ..., 1, 0, 0], dtype=int64)

# %% [markdown]
# **Wydzielamy zbiór argumentów**

# %% [markdown]
# Usuwamy HIGH, LOW, CLOSE, VOL, gdyż są to dane z przyszłości

# %% [markdown]
# Usuwamy również OPEN gdyż w takiej obróbce mogłoby ono tylko zaciemnić dane

# %% [markdown]
# Ponadto usuwamy również DATE, gdyż nie wnoszą one aktualnie wartościowych informacji i mogą zniekształcić nasz model

# %%
X = data_stock_modified.drop(['High', 'Low', 'Close', 'Volume', 'Open', 'Date', 'Increased'], axis=1)

# %%
X.head(8)
# Out:
#      Vol_1_ago  Increased_1_ago   Vol_2_ago  Increased_2_ago   Vol_3_ago  \
# 50  2573183333                0  1927211111                0  1835411111
# 51  2079466667                1  2573183333                0  1927211111
# 52  2010155556                1  2079466667                1  2573183333
# 53  2017311111                0  2010155556                1  2079466667
# 54  1985988889                0  2017311111                0  2010155556
# 55  1920111111                1  1985988889                0  2017311111
# 56  1923966667                0  1920111111                1  1985988889
# 57  2322233333                0  1923966667                0  1920111111
#
#     Increased_3_ago   Vol_4_ago  Increased_4_ago   Vol_5_ago  Increased_5_ago  \
# 50                0  2187938889                0  2123383333                0
# 51                0  1835411111                0  2187938889                0
# 52                0  1927211111                0  1835411111                0
# 53                1  2573183333                0  1927211111                0
# 54                1  2079466667                1  2573183333                0
# 55                0  2010155556                1  2079466667                1
# 56                0  2017311111                0  2010155556                1
# 57                1  1985988889                0  2017311111                0
#
#     ...  Vol_46_ago  Increased_46_ago  Vol_47_ago  Increased_47_ago  \
# 50  ...  2560305556                 1  2289400000                 1
# 51  ...  1877611111                 1  2560305556                 1
# 52  ...  2079144444                 1  1877611111                 1
# 53  ...  2275961111                 1  2079144444                 1
# 54  ...  2338827778                 1  2275961111                 1
# 55  ...  2154211111                 0  2338827778                 1
# 56  ...  2010022222                 1  2154211111                 0
# 57  ...  2160844444                 0  2010022222                 1
#
#     Vol_48_ago  Increased_48_ago  Vol_49_ago  Increased_49_ago  Vol_50_ago  \
# 50  2502422222                 1  2353083333                 0  2032783333
# 51  2289400000                 1  2502422222                 1  2353083333
# 52  2560305556                 1  2289400000                 1  2502422222
# 53  1877611111                 1  2560305556                 1  2289400000
# 54  2079144444                 1  1877611111                 1  2560305556
# 55  2275961111                 1  2079144444                 1  1877611111
# 56  2338827778                 1  2275961111                 1  2079144444
# 57  2154211111                 0  2338827778                 1  2275961111
#
#     Increased_50_ago
# 50                 0
# 51                 0
# 52                 1
# 53                 1
# 54                 1
# 55                 1
# 56                 1
# 57                 1
#
# [8 rows x 100 columns]

# %% [markdown]
# # Modele

# %%
from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=None, shuffle=False)

# %%
X_train
# Out:
#        Vol_1_ago  Increased_1_ago   Vol_2_ago  Increased_2_ago   Vol_3_ago  \
# 245   2108744444                1  2059283333                1  1880044444
# 564   2241488889                1  1785011111                0  1773238889
# 621   1725588889                1  1878711111                0  1883861111
# 983   1935605556                1  1956033333                1  2089044444
# 1274  1988766667                1  1951700000                1  2040205556
# ...          ...              ...         ...              ...         ...
# 1136  2103627778                1  2138194444                0  1947772222
# 862   1664744444                0  2070700000                1  2265855556
# 676   1865677778                0  1978316667                1  2229172222
# 1568  1676377778                0  1882550000                0  1860761111
# 923   2295772222                1  2403700000                0  2067705556
#
#       Increased_3_ago   Vol_4_ago  Increased_4_ago   Vol_5_ago  \
# 245                 1  1741861111                1  1668338889
# 564                 0  1714288889                0  1786355556
# 621                 1  1849300000                0  1524955556
# 983                 1  3712816667                0  2404105556
# 1274                0  2097550000                1  1956061111
# ...               ...         ...              ...         ...
# 1136                0  2243800000                1  2035688889
# 862                 1  2043866667                0  2791927778
# 676                 1  2326994444                0  2195055556
# 1568                0  1879672222                0  1796866667
# 923                 0  2273072222                0  1772516667
#
#       Increased_5_ago  ...  Vol_46_ago  Increased_46_ago  Vol_47_ago  \
# 245                 0  ...  1919750000                 0  1426411111
# 564                 1  ...  1891044444                 0  1891655556
# 621                 1  ...  1567811111                 0  1619822222
# 983                 0  ...  1850833333                 0  1826288889
# 1274                1  ...  2448316667                 0  2143105556
# ...               ...  ...         ...               ...         ...
# 1136                1  ...  2508005556                 0  1710638889
# 862                 0  ...  2263872222                 0  1970150000
# 676                 0  ...  2105366667                 0  2329444444
# 1568                1  ...  2047172222                 1  2224300000
# 923                 0  ...  2131527778                 0  2150022222
#
#       Increased_47_ago  Vol_48_ago  Increased_48_ago  Vol_49_ago  \
# 245                  1  2026305556                 1  2099733333
# 564                  1  2034205556                 0  1900616667
# 621                  1  1669855556                 1  1680566667
# 983                  1  1997461111                 1  2081272222
# 1274                 1  2241394444                 0  2158044444
# ...                ...         ...               ...         ...
# 1136                 1  1794994444                 0  2143977778
# 862                  1  1910416667                 0  1875433333
# 676                  0  1915694444                 0  1768500000
# 1568                 1  1929372222                 1  2253216667
# 923                  0  2096005556                 0  2052261111
#
#       Increased_49_ago  Vol_50_ago  Increased_50_ago
# 245                  0  2420272222                 0
# 564                  1  1730416667                 1
# 621                  1  1885233333                 0
# 983                  1  2024772222                 0
# 1274                 1  2333655556                 1
# ...                ...         ...               ...
# 1136                 1  2015188889                 1
# 862                  1  2020372222                 1
# 676                  0  1557400000                 1
# 1568                 1  3155594444                 1
# 923                  0  1857605556                 0
#
# [1233 rows x 100 columns]

# %% [markdown]
# **Skalowanie**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (1233, 100)

# %%
y_train.shape
# Out:
# (1233,)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC

seed=123
# kfold = StratifiedKFold(n_splits=5, random_state=seed, shuffle=True)
kfold = StratifiedKFold(n_splits=5)

# %%
X_train
# Out:
# array([[ 0.37286584,  0.92268703,  0.22604823, ..., -1.10346087,
#          1.28199109, -1.07148664],
#        [ 0.73421795,  0.92268703, -0.51290648, ...,  0.90623965,
#         -0.70745259,  0.93328275],
#        [-0.6701463 ,  0.92268703, -0.26045636, ...,  0.90623965,
#         -0.26098371, -1.07148664],
#        ...,
#        [-0.28880141, -1.08379111,  0.00790474, ..., -1.10346087,
#         -1.20640764,  0.93328275],
#        [-0.804107  , -1.08379111, -0.25011348, ...,  0.90623965,
#          3.40255406,  0.93328275],
#        [ 0.88198606,  0.92268703,  1.15398878, ..., -1.10346087,
#         -0.34065822, -1.07148664]])

# %%
from sklearn.linear_model import LogisticRegression
pipe = Pipeline([
    ('classifier', LogisticRegression(max_iter=10000))])

param_grid = {
            'classifier__C' : np.linspace(0, 0.1, 100),
            'classifier__solver':['newton-cg', 'lbfgs', 'liblinear'],
            'classifier__penalty' : ['l1', 'l2']
}

grid_4 = GridSearchCV(pipe, param_grid, verbose=10,scoring='accuracy')
grid_4.fit(X_train, y_train)
grid_4.best_params_

# %%
from sklearn import  metrics
metrics.accuracy_score(y_test, grid_4.predict(X_test))
# Out:
# 0.5016181229773463

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Flatten
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import BatchNormalization

from tensorflow.keras.callbacks import History

history_sgd = History()
model = Sequential()

model.add(Flatten(input_shape=((X_train).shape[1],)))

model.add(Dense(300))
model.add(BatchNormalization())
model.add(Activation("elu"))
model.add(Dropout(0.3))

model.add(Dense(150))
model.add(BatchNormalization())
model.add(Activation("elu"))
model.add(Dropout(0.3))

model.add(Dense(50))
model.add(BatchNormalization())
model.add(Activation("elu"))
model.add(Dropout(0.3))

model.add(Dense(1,activation="sigmoid"))



model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 100)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 300)               30300
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 300)               1200
# _________________________________________________________________
# activation_9 (Activation)    (None, 300)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 150)               45150
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 150)               600
# _________________________________________________________________
# activation_10 (Activation)   (None, 150)               0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 150)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 50)                7550
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 50)                200
# _________________________________________________________________
# activation_11 (Activation)   (None, 50)                0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 85,051
# Trainable params: 84,051
# Non-trainable params: 1,000
# _________________________________________________________________

# %%
model.compile(loss="binary_crossentropy",optimizer='adam', metrics=["accuracy"])

# %%
model.fit(X_train, y_train, batch_size=32,epochs=200, validation_data=(X_test, y_test), callbacks=[history_sgd])
# Out:
# Epoch 1/200
# 39/39 [==============================] - 0s 7ms/step - loss: 0.8448 - accuracy: 0.5101 - val_loss: 0.7167 - val_accuracy: 0.5340
# Epoch 2/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.7381 - accuracy: 0.5572 - val_loss: 0.7112 - val_accuracy: 0.5243
# Epoch 3/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.7084 - accuracy: 0.5718 - val_loss: 0.7198 - val_accuracy: 0.4919
# Epoch 4/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.7015 - accuracy: 0.5734 - val_loss: 0.7134 - val_accuracy: 0.5210
# Epoch 5/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6968 - accuracy: 0.5823 - val_loss: 0.7251 - val_accuracy: 0.5210
# Epoch 6/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6678 - accuracy: 0.5994 - val_loss: 0.7218 - val_accuracy: 0.5437
# Epoch 7/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6663 - accuracy: 0.6067 - val_loss: 0.7218 - val_accuracy: 0.5599
# Epoch 8/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6538 - accuracy: 0.6204 - val_loss: 0.7245 - val_accuracy: 0.5210
# Epoch 9/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6160 - accuracy: 0.6456 - val_loss: 0.7321 - val_accuracy: 0.5307
# Epoch 10/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6204 - accuracy: 0.6602 - val_loss: 0.7521 - val_accuracy: 0.5307
# Epoch 11/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6198 - accuracy: 0.6464 - val_loss: 0.7405 - val_accuracy: 0.5566
# Epoch 12/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6253 - accuracy: 0.6618 - val_loss: 0.7563 - val_accuracy: 0.5405
# Epoch 13/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5986 - accuracy: 0.6756 - val_loss: 0.7641 - val_accuracy: 0.5437
# Epoch 14/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.6113 - accuracy: 0.6529 - val_loss: 0.7683 - val_accuracy: 0.5372
# Epoch 15/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5785 - accuracy: 0.6926 - val_loss: 0.7661 - val_accuracy: 0.5178
# Epoch 16/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5713 - accuracy: 0.7032 - val_loss: 0.7809 - val_accuracy: 0.5437
# Epoch 17/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5734 - accuracy: 0.7007 - val_loss: 0.7956 - val_accuracy: 0.5405
# Epoch 18/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5816 - accuracy: 0.6894 - val_loss: 0.7900 - val_accuracy: 0.5243
# Epoch 19/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5332 - accuracy: 0.7413 - val_loss: 0.7985 - val_accuracy: 0.5275
# Epoch 20/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5523 - accuracy: 0.7113 - val_loss: 0.8159 - val_accuracy: 0.5243
# Epoch 21/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5405 - accuracy: 0.7251 - val_loss: 0.8283 - val_accuracy: 0.5210
# Epoch 22/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5245 - accuracy: 0.7315 - val_loss: 0.8300 - val_accuracy: 0.5049
# Epoch 23/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5183 - accuracy: 0.7518 - val_loss: 0.8327 - val_accuracy: 0.5081
# Epoch 24/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4817 - accuracy: 0.7680 - val_loss: 0.8538 - val_accuracy: 0.5113
# Epoch 25/200
# 39/39 [==============================] - 0s 4ms/step - loss: 0.4872 - accuracy: 0.7624 - val_loss: 0.8396 - val_accuracy: 0.5113
# Epoch 26/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4739 - accuracy: 0.7656 - val_loss: 0.8682 - val_accuracy: 0.5146
# Epoch 27/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4831 - accuracy: 0.7672 - val_loss: 0.8388 - val_accuracy: 0.5372
# Epoch 28/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4684 - accuracy: 0.7843 - val_loss: 0.9117 - val_accuracy: 0.5178
# Epoch 29/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4465 - accuracy: 0.7924 - val_loss: 0.8992 - val_accuracy: 0.5113
# Epoch 30/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4225 - accuracy: 0.7989 - val_loss: 0.9255 - val_accuracy: 0.5307
# Epoch 31/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4341 - accuracy: 0.8005 - val_loss: 0.9220 - val_accuracy: 0.5178
# Epoch 32/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4254 - accuracy: 0.7972 - val_loss: 0.9178 - val_accuracy: 0.5307
# Epoch 33/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3881 - accuracy: 0.8240 - val_loss: 0.9496 - val_accuracy: 0.5049
# Epoch 34/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4002 - accuracy: 0.8297 - val_loss: 0.9931 - val_accuracy: 0.5243
# Epoch 35/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3983 - accuracy: 0.8143 - val_loss: 0.9996 - val_accuracy: 0.5113
# Epoch 36/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3738 - accuracy: 0.8240 - val_loss: 0.9902 - val_accuracy: 0.5243
# Epoch 37/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.4003 - accuracy: 0.8208 - val_loss: 1.0037 - val_accuracy: 0.5049
# Epoch 38/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3586 - accuracy: 0.8491 - val_loss: 1.1220 - val_accuracy: 0.5437
# Epoch 39/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3556 - accuracy: 0.8321 - val_loss: 1.1017 - val_accuracy: 0.5146
# Epoch 40/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3815 - accuracy: 0.8256 - val_loss: 1.0506 - val_accuracy: 0.5372
# Epoch 41/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3169 - accuracy: 0.8564 - val_loss: 1.0735 - val_accuracy: 0.5146
# Epoch 42/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3268 - accuracy: 0.8605 - val_loss: 1.0550 - val_accuracy: 0.5340
# Epoch 43/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3100 - accuracy: 0.8613 - val_loss: 1.0725 - val_accuracy: 0.5275
# Epoch 44/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3159 - accuracy: 0.8637 - val_loss: 1.1151 - val_accuracy: 0.5113
# Epoch 45/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3235 - accuracy: 0.8589 - val_loss: 1.1028 - val_accuracy: 0.5372
# Epoch 46/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2869 - accuracy: 0.8719 - val_loss: 1.1395 - val_accuracy: 0.5210
# Epoch 47/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2777 - accuracy: 0.8889 - val_loss: 1.1403 - val_accuracy: 0.5081
# Epoch 48/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2940 - accuracy: 0.8727 - val_loss: 1.1736 - val_accuracy: 0.5696
# Epoch 49/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.3003 - accuracy: 0.8646 - val_loss: 1.1094 - val_accuracy: 0.5275
# Epoch 50/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2673 - accuracy: 0.8921 - val_loss: 1.1676 - val_accuracy: 0.5275
# Epoch 51/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2467 - accuracy: 0.9019 - val_loss: 1.1592 - val_accuracy: 0.5146
# Epoch 52/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2792 - accuracy: 0.8913 - val_loss: 1.2296 - val_accuracy: 0.5243
# Epoch 53/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2719 - accuracy: 0.8897 - val_loss: 1.2347 - val_accuracy: 0.5307
# Epoch 54/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2480 - accuracy: 0.8954 - val_loss: 1.1996 - val_accuracy: 0.5469
# Epoch 55/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2355 - accuracy: 0.9019 - val_loss: 1.2682 - val_accuracy: 0.5113
# Epoch 56/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2669 - accuracy: 0.8921 - val_loss: 1.2068 - val_accuracy: 0.5307
# Epoch 57/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2434 - accuracy: 0.9108 - val_loss: 1.2366 - val_accuracy: 0.5340
# Epoch 58/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2357 - accuracy: 0.9011 - val_loss: 1.2342 - val_accuracy: 0.5437
# Epoch 59/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1936 - accuracy: 0.9173 - val_loss: 1.2517 - val_accuracy: 0.5210
# Epoch 60/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2185 - accuracy: 0.9140 - val_loss: 1.3485 - val_accuracy: 0.5340
# Epoch 61/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2427 - accuracy: 0.8962 - val_loss: 1.3840 - val_accuracy: 0.5340
# Epoch 62/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2193 - accuracy: 0.9189 - val_loss: 1.3575 - val_accuracy: 0.5405
# Epoch 63/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2176 - accuracy: 0.9100 - val_loss: 1.3812 - val_accuracy: 0.5372
# Epoch 64/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1968 - accuracy: 0.9238 - val_loss: 1.4528 - val_accuracy: 0.5243
# Epoch 65/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2082 - accuracy: 0.9157 - val_loss: 1.3968 - val_accuracy: 0.5210
# Epoch 66/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2033 - accuracy: 0.9189 - val_loss: 1.3623 - val_accuracy: 0.5307
# Epoch 67/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2098 - accuracy: 0.9132 - val_loss: 1.3790 - val_accuracy: 0.5243
# Epoch 68/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2079 - accuracy: 0.9205 - val_loss: 1.3907 - val_accuracy: 0.5178
# Epoch 69/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2228 - accuracy: 0.9108 - val_loss: 1.3421 - val_accuracy: 0.5275
# Epoch 70/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1817 - accuracy: 0.9278 - val_loss: 1.3634 - val_accuracy: 0.5178
# Epoch 71/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.2033 - accuracy: 0.9108 - val_loss: 1.3906 - val_accuracy: 0.5437
# Epoch 72/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1864 - accuracy: 0.9278 - val_loss: 1.3866 - val_accuracy: 0.5275
# Epoch 73/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1546 - accuracy: 0.9367 - val_loss: 1.4081 - val_accuracy: 0.5307
# Epoch 74/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1647 - accuracy: 0.9359 - val_loss: 1.4356 - val_accuracy: 0.5437
# Epoch 75/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1767 - accuracy: 0.9254 - val_loss: 1.4887 - val_accuracy: 0.5275
# Epoch 76/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1875 - accuracy: 0.9294 - val_loss: 1.4857 - val_accuracy: 0.5210
# Epoch 77/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1585 - accuracy: 0.9303 - val_loss: 1.5031 - val_accuracy: 0.5113
# Epoch 78/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1728 - accuracy: 0.9303 - val_loss: 1.4937 - val_accuracy: 0.5307
# Epoch 79/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1846 - accuracy: 0.9319 - val_loss: 1.5321 - val_accuracy: 0.5243
# Epoch 80/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1751 - accuracy: 0.9335 - val_loss: 1.5610 - val_accuracy: 0.5178
# Epoch 81/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1702 - accuracy: 0.9359 - val_loss: 1.5429 - val_accuracy: 0.5469
# Epoch 82/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1543 - accuracy: 0.9440 - val_loss: 1.4984 - val_accuracy: 0.5372
# Epoch 83/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1811 - accuracy: 0.9311 - val_loss: 1.5290 - val_accuracy: 0.5113
# Epoch 84/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1539 - accuracy: 0.9303 - val_loss: 1.6429 - val_accuracy: 0.5243
# Epoch 85/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1604 - accuracy: 0.9376 - val_loss: 1.6634 - val_accuracy: 0.5210
# Epoch 86/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1620 - accuracy: 0.9367 - val_loss: 1.6114 - val_accuracy: 0.5146
# Epoch 87/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1640 - accuracy: 0.9319 - val_loss: 1.5740 - val_accuracy: 0.5049
# Epoch 88/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1389 - accuracy: 0.9392 - val_loss: 1.6527 - val_accuracy: 0.5016
# Epoch 89/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1456 - accuracy: 0.9473 - val_loss: 1.6859 - val_accuracy: 0.5210
# Epoch 90/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1646 - accuracy: 0.9400 - val_loss: 1.5382 - val_accuracy: 0.5307
# Epoch 91/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1445 - accuracy: 0.9384 - val_loss: 1.5620 - val_accuracy: 0.5113
# Epoch 92/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1521 - accuracy: 0.9473 - val_loss: 1.5964 - val_accuracy: 0.5016
# Epoch 93/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1482 - accuracy: 0.9416 - val_loss: 1.5474 - val_accuracy: 0.5243
# Epoch 94/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1351 - accuracy: 0.9505 - val_loss: 1.6709 - val_accuracy: 0.5113
# Epoch 95/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1239 - accuracy: 0.9505 - val_loss: 1.6593 - val_accuracy: 0.5340
# Epoch 96/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1348 - accuracy: 0.9513 - val_loss: 1.6632 - val_accuracy: 0.5178
# Epoch 97/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1390 - accuracy: 0.9376 - val_loss: 1.6452 - val_accuracy: 0.5146
# Epoch 98/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1446 - accuracy: 0.9416 - val_loss: 1.6933 - val_accuracy: 0.5113
# Epoch 99/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1400 - accuracy: 0.9448 - val_loss: 1.6118 - val_accuracy: 0.5631
# Epoch 100/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.9570 - val_loss: 1.6092 - val_accuracy: 0.5113
# Epoch 101/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1422 - accuracy: 0.9432 - val_loss: 1.6052 - val_accuracy: 0.5081
# Epoch 102/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1246 - accuracy: 0.9538 - val_loss: 1.7221 - val_accuracy: 0.5113
# Epoch 103/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1452 - accuracy: 0.9457 - val_loss: 1.6450 - val_accuracy: 0.5307
# Epoch 104/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.9538 - val_loss: 1.6594 - val_accuracy: 0.5307
# Epoch 105/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1544 - accuracy: 0.9408 - val_loss: 1.6519 - val_accuracy: 0.5113
# Epoch 106/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1238 - accuracy: 0.9473 - val_loss: 1.6050 - val_accuracy: 0.5275
# Epoch 107/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1175 - accuracy: 0.9538 - val_loss: 1.7143 - val_accuracy: 0.5405
# Epoch 108/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1027 - accuracy: 0.9619 - val_loss: 1.7182 - val_accuracy: 0.5210
# Epoch 109/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0879 - accuracy: 0.9692 - val_loss: 1.6830 - val_accuracy: 0.5178
# Epoch 110/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1164 - accuracy: 0.9513 - val_loss: 1.6646 - val_accuracy: 0.5146
# Epoch 111/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1089 - accuracy: 0.9578 - val_loss: 1.7222 - val_accuracy: 0.5405
# Epoch 112/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1193 - accuracy: 0.9481 - val_loss: 1.7647 - val_accuracy: 0.5372
# Epoch 113/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1432 - accuracy: 0.9351 - val_loss: 1.8125 - val_accuracy: 0.5016
# Epoch 114/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1149 - accuracy: 0.9578 - val_loss: 1.7447 - val_accuracy: 0.5146
# Epoch 115/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1148 - accuracy: 0.9603 - val_loss: 1.6514 - val_accuracy: 0.5340
# Epoch 116/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1163 - accuracy: 0.9627 - val_loss: 1.6988 - val_accuracy: 0.5275
# Epoch 117/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1081 - accuracy: 0.9530 - val_loss: 1.8045 - val_accuracy: 0.5146
# Epoch 118/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1144 - accuracy: 0.9546 - val_loss: 1.8253 - val_accuracy: 0.5113
# Epoch 119/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1007 - accuracy: 0.9651 - val_loss: 1.8214 - val_accuracy: 0.5437
# Epoch 120/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1232 - accuracy: 0.9521 - val_loss: 1.8085 - val_accuracy: 0.5340
# Epoch 121/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1026 - accuracy: 0.9594 - val_loss: 1.7541 - val_accuracy: 0.5210
# Epoch 122/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0989 - accuracy: 0.9586 - val_loss: 1.8776 - val_accuracy: 0.5113
# Epoch 123/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0947 - accuracy: 0.9627 - val_loss: 1.8747 - val_accuracy: 0.4984
# Epoch 124/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1118 - accuracy: 0.9546 - val_loss: 1.8014 - val_accuracy: 0.5307
# Epoch 125/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1278 - accuracy: 0.9546 - val_loss: 1.8315 - val_accuracy: 0.5405
# Epoch 126/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0929 - accuracy: 0.9619 - val_loss: 1.7681 - val_accuracy: 0.5534
# Epoch 127/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1068 - accuracy: 0.9578 - val_loss: 1.8672 - val_accuracy: 0.5405
# Epoch 128/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1081 - accuracy: 0.9570 - val_loss: 1.7941 - val_accuracy: 0.5275
# Epoch 129/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0891 - accuracy: 0.9635 - val_loss: 1.8038 - val_accuracy: 0.5243
# Epoch 130/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1157 - accuracy: 0.9586 - val_loss: 1.8050 - val_accuracy: 0.5469
# Epoch 131/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1020 - accuracy: 0.9627 - val_loss: 1.7076 - val_accuracy: 0.5502
# Epoch 132/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1122 - accuracy: 0.9562 - val_loss: 1.8338 - val_accuracy: 0.5502
# Epoch 133/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1123 - accuracy: 0.9594 - val_loss: 1.8815 - val_accuracy: 0.5113
# Epoch 134/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1116 - accuracy: 0.9619 - val_loss: 1.7646 - val_accuracy: 0.5534
# Epoch 135/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1216 - accuracy: 0.9562 - val_loss: 1.7447 - val_accuracy: 0.5405
# Epoch 136/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0929 - accuracy: 0.9643 - val_loss: 1.7105 - val_accuracy: 0.5534
# Epoch 137/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 0.9749 - val_loss: 1.8445 - val_accuracy: 0.5340
# Epoch 138/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0947 - accuracy: 0.9643 - val_loss: 1.7601 - val_accuracy: 0.5599
# Epoch 139/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1025 - accuracy: 0.9643 - val_loss: 1.7605 - val_accuracy: 0.5437
# Epoch 140/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0942 - accuracy: 0.9635 - val_loss: 1.8440 - val_accuracy: 0.5243
# Epoch 141/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1102 - accuracy: 0.9530 - val_loss: 1.9073 - val_accuracy: 0.5210
# Epoch 142/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 0.9716 - val_loss: 1.9066 - val_accuracy: 0.5081
# Epoch 143/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0955 - accuracy: 0.9635 - val_loss: 1.8536 - val_accuracy: 0.5243
# Epoch 144/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1093 - accuracy: 0.9578 - val_loss: 1.8447 - val_accuracy: 0.5372
# Epoch 145/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1286 - accuracy: 0.9570 - val_loss: 1.8808 - val_accuracy: 0.5113
# Epoch 146/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0929 - accuracy: 0.9708 - val_loss: 1.8581 - val_accuracy: 0.4887
# Epoch 147/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0769 - accuracy: 0.9732 - val_loss: 1.8401 - val_accuracy: 0.5113
# Epoch 148/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0861 - accuracy: 0.9659 - val_loss: 1.8308 - val_accuracy: 0.5502
# Epoch 149/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0902 - accuracy: 0.9684 - val_loss: 1.8455 - val_accuracy: 0.5340
# Epoch 150/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0743 - accuracy: 0.9732 - val_loss: 1.9130 - val_accuracy: 0.5081
# Epoch 151/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0688 - accuracy: 0.9781 - val_loss: 2.0351 - val_accuracy: 0.5081
# Epoch 152/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1019 - accuracy: 0.9578 - val_loss: 1.9924 - val_accuracy: 0.5178
# Epoch 153/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0899 - accuracy: 0.9594 - val_loss: 1.9687 - val_accuracy: 0.5405
# Epoch 154/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0651 - accuracy: 0.9789 - val_loss: 1.9207 - val_accuracy: 0.5210
# Epoch 155/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1089 - accuracy: 0.9619 - val_loss: 2.0653 - val_accuracy: 0.5243
# Epoch 156/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0722 - accuracy: 0.9724 - val_loss: 2.0134 - val_accuracy: 0.5146
# Epoch 157/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0908 - accuracy: 0.9708 - val_loss: 1.8771 - val_accuracy: 0.5178
# Epoch 158/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9667 - val_loss: 2.0006 - val_accuracy: 0.5113
# Epoch 159/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.1141 - accuracy: 0.9546 - val_loss: 1.9335 - val_accuracy: 0.5243
# Epoch 160/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0898 - accuracy: 0.9708 - val_loss: 1.8956 - val_accuracy: 0.5372
# Epoch 161/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0636 - accuracy: 0.9740 - val_loss: 1.9357 - val_accuracy: 0.5016
# Epoch 162/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 0.9732 - val_loss: 1.9731 - val_accuracy: 0.5599
# Epoch 163/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0930 - accuracy: 0.9667 - val_loss: 1.9804 - val_accuracy: 0.5016
# Epoch 164/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0861 - accuracy: 0.9643 - val_loss: 2.0843 - val_accuracy: 0.5210
# Epoch 165/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0895 - accuracy: 0.9651 - val_loss: 1.9850 - val_accuracy: 0.5437
# Epoch 166/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0984 - accuracy: 0.9667 - val_loss: 1.8796 - val_accuracy: 0.5243
# Epoch 167/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0886 - accuracy: 0.9659 - val_loss: 1.9729 - val_accuracy: 0.5243
# Epoch 168/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0552 - accuracy: 0.9773 - val_loss: 1.9579 - val_accuracy: 0.5146
# Epoch 169/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0636 - accuracy: 0.9805 - val_loss: 2.0103 - val_accuracy: 0.5372
# Epoch 170/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0925 - accuracy: 0.9659 - val_loss: 2.0152 - val_accuracy: 0.5275
# Epoch 171/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0907 - accuracy: 0.9684 - val_loss: 2.0363 - val_accuracy: 0.4887
# Epoch 172/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0925 - accuracy: 0.9627 - val_loss: 2.0076 - val_accuracy: 0.5243
# Epoch 173/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0834 - accuracy: 0.9659 - val_loss: 2.0555 - val_accuracy: 0.4984
# Epoch 174/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 0.9659 - val_loss: 2.0486 - val_accuracy: 0.5178
# Epoch 175/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0698 - accuracy: 0.9773 - val_loss: 2.0074 - val_accuracy: 0.5081
# Epoch 176/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0817 - accuracy: 0.9732 - val_loss: 2.1688 - val_accuracy: 0.5113
# Epoch 177/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.9708 - val_loss: 1.9967 - val_accuracy: 0.5210
# Epoch 178/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0836 - accuracy: 0.9667 - val_loss: 2.0377 - val_accuracy: 0.5502
# Epoch 179/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0898 - accuracy: 0.9667 - val_loss: 2.0807 - val_accuracy: 0.5469
# Epoch 180/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0682 - accuracy: 0.9813 - val_loss: 1.9787 - val_accuracy: 0.5502
# Epoch 181/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0908 - accuracy: 0.9667 - val_loss: 2.0173 - val_accuracy: 0.5340
# Epoch 182/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0880 - accuracy: 0.9700 - val_loss: 1.9154 - val_accuracy: 0.5534
# Epoch 183/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0561 - accuracy: 0.9789 - val_loss: 1.9471 - val_accuracy: 0.5340
# Epoch 184/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0611 - accuracy: 0.9797 - val_loss: 1.9293 - val_accuracy: 0.5372
# Epoch 185/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0582 - accuracy: 0.9773 - val_loss: 2.1452 - val_accuracy: 0.5340
# Epoch 186/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0578 - accuracy: 0.9781 - val_loss: 2.1691 - val_accuracy: 0.5243
# Epoch 187/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9659 - val_loss: 2.0486 - val_accuracy: 0.5631
# Epoch 188/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0790 - accuracy: 0.9684 - val_loss: 2.0323 - val_accuracy: 0.5534
# Epoch 189/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0782 - accuracy: 0.9716 - val_loss: 2.0197 - val_accuracy: 0.5372
# Epoch 190/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0623 - accuracy: 0.9757 - val_loss: 2.1531 - val_accuracy: 0.5275
# Epoch 191/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0737 - accuracy: 0.9765 - val_loss: 2.1530 - val_accuracy: 0.5016
# Epoch 192/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0721 - accuracy: 0.9765 - val_loss: 2.0918 - val_accuracy: 0.5372
# Epoch 193/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0727 - accuracy: 0.9765 - val_loss: 2.0556 - val_accuracy: 0.5437
# Epoch 194/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0715 - accuracy: 0.9700 - val_loss: 2.0676 - val_accuracy: 0.5437
# Epoch 195/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0686 - accuracy: 0.9700 - val_loss: 2.0425 - val_accuracy: 0.5178
# Epoch 196/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0810 - accuracy: 0.9676 - val_loss: 2.0361 - val_accuracy: 0.5243
# Epoch 197/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0718 - accuracy: 0.9749 - val_loss: 2.1134 - val_accuracy: 0.5178
# Epoch 198/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0722 - accuracy: 0.9724 - val_loss: 2.1491 - val_accuracy: 0.5243
# Epoch 199/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9732 - val_loss: 2.2047 - val_accuracy: 0.5307
# Epoch 200/200
# 39/39 [==============================] - 0s 3ms/step - loss: 0.0740 - accuracy: 0.9732 - val_loss: 2.1632 - val_accuracy: 0.5243

# %%
import pandas as pd

pd.DataFrame(history_sgd.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.yticks(np.linspace(0,1,11))
plt.show()

# %% [markdown]
# # Krzywe ROC

# %%
models = []
models.append(('Logistic regression', grid_4))
models.append(('Keras', model))

precision_score = []
recall_score = []
f1_score = []
accuracy_score = []
roc_auc_val = []
plt.figure(figsize=(12, 12))
for name, model in models:
    if((name == 'Keras')):
        precision_score.append(metrics.precision_score(y_test, model.predict_classes(X_test)))
        recall_score.append(metrics.recall_score(y_test, model.predict_classes(X_test)))
        f1_score.append( metrics.f1_score(y_test, model.predict_classes(X_test)))
        accuracy_score.append(metrics.accuracy_score(y_test, model.predict_classes(X_test)))
        
        
        # calculate the fpr and tpr for all thresholds of the classification
        probs = model.predict_proba(X_test)
        preds = probs
        fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
        roc_auc = metrics.auc(fpr, tpr)
        roc_auc_val.append(roc_auc)
        
    else:
        precision_score.append(metrics.precision_score(y_test, model.predict(X_test)))
        recall_score.append(metrics.recall_score(y_test, model.predict(X_test)))
        f1_score.append( metrics.f1_score(y_test, model.predict(X_test)))
        accuracy_score.append(metrics.accuracy_score(y_test, model.predict(X_test)))
        
        # calculate the fpr and tpr for all thresholds of the classification
        probs = model.predict_proba(X_test)
        preds = probs[:,1]
        fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
        roc_auc = metrics.auc(fpr, tpr)
        roc_auc_val.append(roc_auc)
            

    # method I: plt
    import matplotlib.pyplot as plt
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, label = '%s AUC = %0.10f' % (name, roc_auc))
    plt.legend(loc = 'lower right')
    plt.plot([-0.1, 1.1], [0, 1],'r--')
    plt.xlim([-0.1, 1.1])
    plt.ylim([-0.1, 1.1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
plt.rcParams['figure.figsize'] = [2, 2]
plt.show()

# %%
d = {
     'precision_score': precision_score, 
     'recall_score': recall_score, 
     'f1_score': f1_score,
     'accuracy_score' : accuracy_score,
     'roc_auc': roc_auc_val
    }
df = pd.DataFrame(data=d)
df.insert(loc=0, column='Method', value=[model[0] for model in models])
df.sort_values(by='accuracy_score', ascending=False)
# Out:
#                 Method  precision_score  recall_score  f1_score  \
# 1                Keras         0.522989      0.587097  0.553191
# 0  Logistic regression         0.501618      1.000000  0.668103
#
#    accuracy_score   roc_auc
# 1        0.524272  0.539610
# 0        0.501618  0.549958
